# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "5"

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
from sklearn.model_selection import StratifiedKFold
from joblib import load, dump
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import confusion_matrix
from fastai import *
from fastai.vision import *
from fastai.callbacks import *
from torchvision import models as md
from torch import nn
from torch.nn import functional as F
import re
import math
import collections
from functools import partial
from torch.utils import model_zoo
from sklearn import metrics
from collections import Counter
import json
from efficientnet_pytorch import EfficientNet
from utils import *

# %%
import random

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
SEED = 2019
seed_everything(SEED)

# %%
current_time = get_BJ_time()
print(current_time)
# Out:
# 0814_17-00-41

# %% [markdown]
# # Reading data and Basic EDA(Exploratory Data Analysis)
#
# Here I am going to open the dataset with pandas, check distribution of labels.

# %%
df_2015 = pd.read_csv('../input/aptos-data-split/df_2015_raw.csv')
df_2019 = pd.read_csv('../input/aptos-data-split/df_2019_sigmaX30.csv')

df = pd.concat([df_2015, df_2019]).reset_index(drop=True) # merge train val together
df['is_valid'] = [False]*df_2015.shape[0] + [True]*df_2019.shape[0]

test_df = pd.read_csv('../input/aptos2019-blindness-detection/sample_submission.csv')

# %%
model_name = 'efficientnet-b7'
bs = 20 #smaller batch size is better for training, but may take longer
sz = 300
# sz = EfficientNet.get_image_size(model_name)  # get model input size
tfms = get_transforms(do_flip=True,flip_vert=True, max_rotate=0, max_zoom=1.2, max_warp=0)

# %%
data = (ImageList.from_df(df=df_2019,path='./',cols='path')
        .split_from_df("is_valid")
        .label_from_df(cols='diagnosis',label_cls=FloatList) 
        .transform(tfms,size=sz,resize_method=ResizeMethod.SQUISH,padding_mode='zeros') 
        .databunch(bs=bs,num_workers=4) 
        .normalize(imagenet_stats)  
       )
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (2929 items)
# x: ImageList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: FloatList
# 0.0,0.0,1.0,2.0,1.0
# Path: .;
#
# Valid: LabelList (733 items)
# x: ImageList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: FloatList
# 2.0,1.0,0.0,4.0,0.0
# Path: .;
#
# Test: None

# %% [markdown]
# # Training (Transfer learning)

# %% [markdown]
# The Kaggle competition used the Cohen's quadratically weighted kappa so I have that here to compare. This is a better metric when dealing with imbalanced datasets like this one, and for measuring inter-rater agreement for categorical classification (the raters being the human-labeled dataset and the neural network predictions). Here is an implementation based on the scikit-learn's implementation, but converted to a pytorch tensor, as that is what fastai uses.

# %%
def qk(y_pred, y):
    return torch.tensor(cohen_kappa_score(torch.round(y_pred), y, weights='quadratic'), device='cuda:0')

# %% [markdown]
# ## EfficientNet

# %%
model = EfficientNet.from_pretrained(model_name, num_classes=1)
# Out:
# Loaded pretrained weights for efficientnet-b7

# %%
learn = Learner(data, 
                model, 
                metrics = [qk],
                callback_fns=[partial(EarlyStoppingCallback, min_delta=0, patience=3)],
                model_dir = '../output/models/').to_fp16()

learn.data.add_test(ImageList.from_df(test_df,
                                      '../input/aptos2019-blindness-detection',
                                      folder='test_images_ben_preprocessing',
                                      suffix='.png'))

# %%
# Freeze layers up to the last one, so weights will not be updated.
# for name, param in learn.model.named_parameters():
#     if name in ["_fc.weight", "_fc.bias"]:
#         param.requires_grad=True
#     else:
#         param.requires_grad=False
        
# Explore lr from `start_lr` to `end_lr` over `num_it` iterations in `learn`. If `stop_div`, stops when loss diverges.
learn.lr_find() 
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 6.31E-07
# Min loss divided by 10: 2.09E-04

# %%
model_save_name = "{}_{}".format(model_name, current_time)
min_grad_lr = learn.recorder.min_grad_lr
learn.fit_one_cycle(40, min_grad_lr, callbacks=[SaveModelCallback(learn, every='improvement', name=model_save_name)])
print("Model save as:", model_save_name)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='36' class='' max='40', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       90.00% [36/40 49:37<05:30]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>qk</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>0.467427</td>
#       <td>0.399203</td>
#       <td>0.855020</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.415542</td>
#       <td>0.406725</td>
#       <td>0.853914</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.394259</td>
#       <td>0.397612</td>
#       <td>0.854992</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.396183</td>
#       <td>0.396184</td>
#       <td>0.853904</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.393385</td>
#       <td>0.381946</td>
#       <td>0.854448</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.376123</td>
#       <td>0.374657</td>
#       <td>0.854848</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.394628</td>
#       <td>0.366348</td>
#       <td>0.859209</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.376179</td>
#       <td>0.349594</td>
#       <td>0.865879</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.370407</td>
#       <td>0.340339</td>
#       <td>0.868452</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.353796</td>
#       <td>0.330820</td>
#       <td>0.868192</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.364096</td>
#       <td>0.321829</td>
#       <td>0.869056</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.336837</td>
#       <td>0.316657</td>
#       <td>0.876845</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.374833</td>
#       <td>0.306351</td>
#       <td>0.878250</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.343474</td>
#       <td>0.306517</td>
#       <td>0.876974</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>14</td>
#       <td>0.331998</td>
#       <td>0.302416</td>
#       <td>0.880046</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>15</td>
#       <td>0.329625</td>
#       <td>0.298911</td>
#       <td>0.879937</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>16</td>
#       <td>0.360730</td>
#       <td>0.296838</td>
#       <td>0.877948</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>17</td>
#       <td>0.317541</td>
#       <td>0.291219</td>
#       <td>0.882990</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>18</td>
#       <td>0.310626</td>
#       <td>0.287085</td>
#       <td>0.882304</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>19</td>
#       <td>0.314639</td>
#       <td>0.285779</td>
#       <td>0.883072</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>20</td>
#       <td>0.309544</td>
#       <td>0.281875</td>
#       <td>0.882793</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>21</td>
#       <td>0.322125</td>
#       <td>0.280606</td>
#       <td>0.886779</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>22</td>
#       <td>0.298973</td>
#       <td>0.275927</td>
#       <td>0.887671</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>23</td>
#       <td>0.316654</td>
#       <td>0.278150</td>
#       <td>0.888993</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>24</td>
#       <td>0.289568</td>
#       <td>0.275427</td>
#       <td>0.888253</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>25</td>
#       <td>0.292970</td>
#       <td>0.275334</td>
#       <td>0.888634</td>
#       <td>01:23</td>
#     </tr>
#     <tr>
#       <td>26</td>
#       <td>0.358441</td>
#       <td>0.275712</td>
#       <td>0.889896</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>27</td>
#       <td>0.296158</td>
#       <td>0.275879</td>
#       <td>0.889192</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>28</td>
#       <td>0.322938</td>
#       <td>0.273590</td>
#       <td>0.891922</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>29</td>
#       <td>0.328716</td>
#       <td>0.274427</td>
#       <td>0.892320</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>30</td>
#       <td>0.299990</td>
#       <td>0.272055</td>
#       <td>0.889033</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>31</td>
#       <td>0.292571</td>
#       <td>0.271637</td>
#       <td>0.889033</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>32</td>
#       <td>0.300108</td>
#       <td>0.270662</td>
#       <td>0.891709</td>
#       <td>01:22</td>
#     </tr>
#     <tr>
#       <td>33</td>
#       <td>0.292631</td>
#       <td>0.272068</td>
#       <td>0.891466</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>34</td>
#       <td>0.275826</td>
#       <td>0.271696</td>
#       <td>0.891922</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>35</td>
#       <td>0.308339</td>
#       <td>0.273901</td>
#       <td>0.891337</td>
#       <td>01:21</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='37' class='' max='37', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [37/37 00:04<00:00]
#     </div>
# Better model found at epoch 0 with valid_loss value: 0.39920303225517273.
# Better model found at epoch 2 with valid_loss value: 0.3976117670536041.
# Better model found at epoch 3 with valid_loss value: 0.3961836099624634.
# Better model found at epoch 4 with valid_loss value: 0.38194552063941956.
# Better model found at epoch 5 with valid_loss value: 0.3746574819087982.
# Better model found at epoch 6 with valid_loss value: 0.3663477897644043.
# Better model found at epoch 7 with valid_loss value: 0.3495940566062927.
# Better model found at epoch 8 with valid_loss value: 0.3403388261795044.
# Better model found at epoch 9 with valid_loss value: 0.33081963658332825.
# Better model found at epoch 10 with valid_loss value: 0.32182908058166504.
# Better model found at epoch 11 with valid_loss value: 0.31665655970573425.
# Better model found at epoch 12 with valid_loss value: 0.3063509464263916.
# Better model found at epoch 14 with valid_loss value: 0.3024161756038666.
# Better model found at epoch 15 with valid_loss value: 0.2989114820957184.
# Better model found at epoch 16 with valid_loss value: 0.2968381345272064.
# Better model found at epoch 17 with valid_loss value: 0.2912193536758423.
# Better model found at epoch 18 with valid_loss value: 0.2870854437351227.
# Better model found at epoch 19 with valid_loss value: 0.2857793867588043.
# Better model found at epoch 20 with valid_loss value: 0.28187480568885803.
# Better model found at epoch 21 with valid_loss value: 0.280606210231781.
# Better model found at epoch 22 with valid_loss value: 0.27592742443084717.
# Better model found at epoch 24 with valid_loss value: 0.27542707324028015.
# Better model found at epoch 25 with valid_loss value: 0.2753344178199768.
# Better model found at epoch 28 with valid_loss value: 0.2735900580883026.
# Better model found at epoch 30 with valid_loss value: 0.27205485105514526.
# Better model found at epoch 31 with valid_loss value: 0.27163705229759216.
# Better model found at epoch 32 with valid_loss value: 0.2706621289253235.
# Epoch 36: early stopping
# Model save as: efficientnet-b7_0814_17-00-41

# %%
learn.recorder.plot_losses()
learn.recorder.plot_metrics()

# %%
learn.load(model_save_name)
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (2929 items)
# x: ImageList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: FloatList
# 0.0,0.0,1.0,2.0,1.0
# Path: .;
#
# Valid: LabelList (733 items)
# x: ImageList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: FloatList
# 2.0,1.0,0.0,4.0,0.0
# Path: .;
#
# Test: LabelList (1928 items)
# x: ImageList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: EmptyLabelList
# ,,,,
# Path: ., model=EfficientNet(
#   (_conv_stem): Conv2dStaticSamePadding(
#     3, 64, kernel_size=(3, 3), stride=(2, 2), bias=False
#     (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   )
#   (_bn0): BatchNorm2d(64, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_blocks): ModuleList(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         64, 64, kernel_size=(3, 3), stride=[1, 1], groups=64, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(64, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         64, 16, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         16, 64, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         64, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (1): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (2): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (3): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (4): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(3, 3), stride=[2, 2], groups=192, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (5): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (6): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (7): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (8): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (9): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (10): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(3, 3), stride=(1, 1), groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 48, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(48, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (11): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         48, 288, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         288, 288, kernel_size=(5, 5), stride=[2, 2], groups=288, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(288, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         288, 12, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         12, 288, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         288, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (12): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (13): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (14): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (15): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (16): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (17): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(5, 5), stride=(1, 1), groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 80, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(80, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (18): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         80, 480, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         480, 480, kernel_size=(3, 3), stride=[2, 2], groups=480, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(480, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         480, 20, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         20, 480, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         480, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (19): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (20): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (21): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (22): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (23): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (24): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (25): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (26): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (27): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(3, 3), stride=(1, 1), groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 160, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(160, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (28): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         160, 960, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         960, 960, kernel_size=(5, 5), stride=[1, 1], groups=960, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(960, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         960, 40, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         40, 960, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         960, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (29): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (30): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (31): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (32): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (33): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (34): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (35): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (36): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (37): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=(1, 1), groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 224, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (38): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         224, 1344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1344, 1344, kernel_size=(5, 5), stride=[2, 2], groups=1344, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1344, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         56, 1344, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1344, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (39): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2304, 2304, kernel_size=(5, 5), stride=(1, 1), groups=2304, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2304, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         96, 2304, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (40): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2304, 2304, kernel_size=(5, 5), stride=(1, 1), groups=2304, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2304, 96, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         96, 2304, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2304, 384, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (41): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         384, 2304, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2304, 2304, kernel_size=(5, 5), stride=(1, 1), groups=2304, bias=False
# ...
#   (448): ParameterModule()
#   (449): ParameterModule()
#   (450): Identity()
#   (451): ParameterModule()
#   (452): ParameterModule()
#   (453): Identity()
#   (454): ParameterModule()
#   (455): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (456): Identity()
#   (457): ParameterModule()
#   (458): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (459): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (460): ParameterModule()
#   (461): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (462): Identity()
#   (463): ParameterModule()
#   (464): ParameterModule()
#   (465): Identity()
#   (466): ParameterModule()
#   (467): ParameterModule()
#   (468): Identity()
#   (469): ParameterModule()
#   (470): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (471): Identity()
#   (472): ParameterModule()
#   (473): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (474): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (475): ParameterModule()
#   (476): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (477): Identity()
#   (478): ParameterModule()
#   (479): ParameterModule()
#   (480): Identity()
#   (481): ParameterModule()
#   (482): ParameterModule()
#   (483): Identity()
#   (484): ParameterModule()
#   (485): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (486): Identity()
#   (487): ParameterModule()
#   (488): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (489): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (490): ParameterModule()
#   (491): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (492): Identity()
#   (493): ParameterModule()
#   (494): ParameterModule()
#   (495): Identity()
#   (496): ParameterModule()
#   (497): ParameterModule()
#   (498): Identity()
#   (499): ParameterModule()
#   (500): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (501): Identity()
#   (502): ParameterModule()
#   (503): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (504): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (505): ParameterModule()
#   (506): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (507): Identity()
#   (508): ParameterModule()
#   (509): ParameterModule()
#   (510): Identity()
#   (511): ParameterModule()
#   (512): ParameterModule()
#   (513): Identity()
#   (514): ParameterModule()
#   (515): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (516): Identity()
#   (517): ParameterModule()
#   (518): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (519): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (520): ParameterModule()
#   (521): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (522): Identity()
#   (523): ParameterModule()
#   (524): ParameterModule()
#   (525): Identity()
#   (526): ParameterModule()
#   (527): ParameterModule()
#   (528): Identity()
#   (529): ParameterModule()
#   (530): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (531): Identity()
#   (532): ParameterModule()
#   (533): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (534): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (535): ParameterModule()
#   (536): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (537): Identity()
#   (538): ParameterModule()
#   (539): ParameterModule()
#   (540): Identity()
#   (541): ParameterModule()
#   (542): ParameterModule()
#   (543): Identity()
#   (544): ParameterModule()
#   (545): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (546): Identity()
#   (547): ParameterModule()
#   (548): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (549): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (550): ParameterModule()
#   (551): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (552): Identity()
#   (553): ParameterModule()
#   (554): ParameterModule()
#   (555): Identity()
#   (556): ParameterModule()
#   (557): ParameterModule()
#   (558): Identity()
#   (559): ParameterModule()
#   (560): BatchNorm2d(224, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (561): Identity()
#   (562): ParameterModule()
#   (563): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (564): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#   (565): ParameterModule()
#   (566): BatchNorm2d(1344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (567): Identity()
#   (568): ParameterModule()
#   (569): ParameterModule()
#   (570): Identity()
#   (571): ParameterModule()
#   (572): ParameterModule()
#   (573): Identity()
#   (574): ParameterModule()
#   (575): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (576): Identity()
#   (577): ParameterModule()
#   (578): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (579): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (580): ParameterModule()
#   (581): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (582): Identity()
#   (583): ParameterModule()
#   (584): ParameterModule()
#   (585): Identity()
#   (586): ParameterModule()
#   (587): ParameterModule()
#   (588): Identity()
#   (589): ParameterModule()
#   (590): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (591): Identity()
#   (592): ParameterModule()
#   (593): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (594): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (595): ParameterModule()
#   (596): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (597): Identity()
#   (598): ParameterModule()
#   (599): ParameterModule()
#   (600): Identity()
#   (601): ParameterModule()
#   (602): ParameterModule()
#   (603): Identity()
#   (604): ParameterModule()
#   (605): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (606): Identity()
#   (607): ParameterModule()
#   (608): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (609): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (610): ParameterModule()
#   (611): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (612): Identity()
#   (613): ParameterModule()
#   (614): ParameterModule()
#   (615): Identity()
#   (616): ParameterModule()
#   (617): ParameterModule()
#   (618): Identity()
#   (619): ParameterModule()
#   (620): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (621): Identity()
#   (622): ParameterModule()
#   (623): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (624): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (625): ParameterModule()
#   (626): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (627): Identity()
#   (628): ParameterModule()
#   (629): ParameterModule()
#   (630): Identity()
#   (631): ParameterModule()
#   (632): ParameterModule()
#   (633): Identity()
#   (634): ParameterModule()
#   (635): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (636): Identity()
#   (637): ParameterModule()
#   (638): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (639): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (640): ParameterModule()
#   (641): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (642): Identity()
#   (643): ParameterModule()
#   (644): ParameterModule()
#   (645): Identity()
#   (646): ParameterModule()
#   (647): ParameterModule()
#   (648): Identity()
#   (649): ParameterModule()
#   (650): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (651): Identity()
#   (652): ParameterModule()
#   (653): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (654): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (655): ParameterModule()
#   (656): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (657): Identity()
#   (658): ParameterModule()
#   (659): ParameterModule()
#   (660): Identity()
#   (661): ParameterModule()
#   (662): ParameterModule()
#   (663): Identity()
#   (664): ParameterModule()
#   (665): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (666): Identity()
#   (667): ParameterModule()
#   (668): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (669): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (670): ParameterModule()
#   (671): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (672): Identity()
#   (673): ParameterModule()
#   (674): ParameterModule()
#   (675): Identity()
#   (676): ParameterModule()
#   (677): ParameterModule()
#   (678): Identity()
#   (679): ParameterModule()
#   (680): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (681): Identity()
#   (682): ParameterModule()
#   (683): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (684): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (685): ParameterModule()
#   (686): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (687): Identity()
#   (688): ParameterModule()
#   (689): ParameterModule()
#   (690): Identity()
#   (691): ParameterModule()
#   (692): ParameterModule()
#   (693): Identity()
#   (694): ParameterModule()
#   (695): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (696): Identity()
#   (697): ParameterModule()
#   (698): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (699): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (700): ParameterModule()
#   (701): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (702): Identity()
#   (703): ParameterModule()
#   (704): ParameterModule()
#   (705): Identity()
#   (706): ParameterModule()
#   (707): ParameterModule()
#   (708): Identity()
#   (709): ParameterModule()
#   (710): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (711): Identity()
#   (712): ParameterModule()
#   (713): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (714): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (715): ParameterModule()
#   (716): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (717): Identity()
#   (718): ParameterModule()
#   (719): ParameterModule()
#   (720): Identity()
#   (721): ParameterModule()
#   (722): ParameterModule()
#   (723): Identity()
#   (724): ParameterModule()
#   (725): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (726): Identity()
#   (727): ParameterModule()
#   (728): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (729): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (730): ParameterModule()
#   (731): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (732): Identity()
#   (733): ParameterModule()
#   (734): ParameterModule()
#   (735): Identity()
#   (736): ParameterModule()
#   (737): ParameterModule()
#   (738): Identity()
#   (739): ParameterModule()
#   (740): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (741): Identity()
#   (742): ParameterModule()
#   (743): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (744): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (745): ParameterModule()
#   (746): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (747): Identity()
#   (748): ParameterModule()
#   (749): ParameterModule()
#   (750): Identity()
#   (751): ParameterModule()
#   (752): ParameterModule()
#   (753): Identity()
#   (754): ParameterModule()
#   (755): BatchNorm2d(384, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (756): Identity()
#   (757): ParameterModule()
#   (758): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (759): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (760): ParameterModule()
#   (761): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (762): Identity()
#   (763): ParameterModule()
#   (764): ParameterModule()
#   (765): Identity()
#   (766): ParameterModule()
#   (767): ParameterModule()
#   (768): Identity()
#   (769): ParameterModule()
#   (770): BatchNorm2d(640, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (771): Identity()
#   (772): ParameterModule()
#   (773): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (774): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (775): ParameterModule()
#   (776): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (777): Identity()
#   (778): ParameterModule()
#   (779): ParameterModule()
#   (780): Identity()
#   (781): ParameterModule()
#   (782): ParameterModule()
#   (783): Identity()
#   (784): ParameterModule()
#   (785): BatchNorm2d(640, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (786): Identity()
#   (787): ParameterModule()
#   (788): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (789): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (790): ParameterModule()
#   (791): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (792): Identity()
#   (793): ParameterModule()
#   (794): ParameterModule()
#   (795): Identity()
#   (796): ParameterModule()
#   (797): ParameterModule()
#   (798): Identity()
#   (799): ParameterModule()
#   (800): BatchNorm2d(640, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (801): Identity()
#   (802): ParameterModule()
#   (803): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (804): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (805): ParameterModule()
#   (806): BatchNorm2d(3840, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (807): Identity()
#   (808): ParameterModule()
#   (809): ParameterModule()
#   (810): Identity()
#   (811): ParameterModule()
#   (812): ParameterModule()
#   (813): Identity()
#   (814): ParameterModule()
#   (815): BatchNorm2d(640, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (816): Identity()
#   (817): ParameterModule()
#   (818): BatchNorm2d(2560, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (819): Linear(in_features=2560, out_features=1, bias=True)
# )], add_time=True, silent=None)

# %% [markdown]
# # Optimize the Metric
# Optimizing the quadratic kappa metric was an important part of the top solutions in the previous competition. Thankfully, @abhishek has already provided code to do this for us. We will use this to improve the score.

# %%
import scipy as sp

# %%
class OptimizedRounder(object):
    """
    Optimize threshold coefficients.
    """
    def __init__(self):
        self.coef_ = 0

    def _kappa_loss(self, coef, X, y):
        """
        Customized loss function.
        
        :param coef: list, shape=[4]
            Threshold.
        :param X: list, shape=[5]
            Prediction.
        :param y: list, shape=[5]
            Golden label.
        """
        X_p = np.copy(X)
        for i, pred in enumerate(X_p):
            if pred < coef[0]:
                X_p[i] = 0
            elif pred >= coef[0] and pred < coef[1]:
                X_p[i] = 1
            elif pred >= coef[1] and pred < coef[2]:
                X_p[i] = 2
            elif pred >= coef[2] and pred < coef[3]:
                X_p[i] = 3
            else:
                X_p[i] = 4
        
        # Cohen's kappa: a statistic that measures inter-annotator agreement.
        ll = metrics.cohen_kappa_score(y, X_p, weights='quadratic')
        return -ll

    def fit(self, X, y):
        """
        :param X: list, shape=[5]
            Prediction.
        :param y: list, shape=[5]
            Golden label.
        """
        # new function with partial application of the given arguments and keywords.
        loss_partial = partial(self._kappa_loss, X=X, y=y)
        initial_coef = [0.5, 1.5, 2.5, 3.5]
        # Minimization of scalar function of one or more variables.
        self.coef_ = sp.optimize.minimize(loss_partial, initial_coef, method='nelder-mead')
        print(-loss_partial(self.coef_['x']))

    def predict(self, X, coef):
        """
        :param X: list, shape=[5]
            Prediction.
        :param coef: list, shape=[4]
            Threshold.
        """
        X_p = np.copy(X)
        for i, pred in enumerate(X_p):
            if pred < coef[0]:
                X_p[i] = 0
            elif pred >= coef[0] and pred < coef[1]:
                X_p[i] = 1
            elif pred >= coef[1] and pred < coef[2]:
                X_p[i] = 2
            elif pred >= coef[2] and pred < coef[3]:
                X_p[i] = 3
            else:
                X_p[i] = 4
        return X_p

    def coefficients(self):
        return self.coef_['x']

# %%
# Return predictions and targets on `ds_type` dataset.
valid_preds = learn.get_preds(ds_type=DatasetType.Valid)
optR = OptimizedRounder()
optR.fit(valid_preds[0],valid_preds[1])
coefficients = optR.coefficients()
print(coefficients)
# Out:
# 0.9075127227837008
# [0.524873 1.572755 2.359902 3.260583]

# %% [markdown]
# # Error Analysis

# %%
valid_pred = optR.predict(valid_preds[0], coefficients)
cm = confusion_matrix(valid_pred,valid_preds[1])

# %%
plot_confusion_matrix(cm, classes=range(5), normalize=False)
# Out:
# Confusion matrix, without normalization
# [[360   7   0   0   0]
#  [  6  38  25   0   2]
#  [  0  22 125   4  11]
#  [  0   1  55  25  32]
#  [  0   0   1   1  18]]

# %%
learn.show_results()

# %% [markdown]
# # Submission

# %%
preds,y = learn.get_preds(DatasetType.Test)
tst_pred = optR.predict(preds, coefficients)
test_df.diagnosis = tst_pred.astype(int)

# %%
save_filename = '{}_submition.csv'.format(model_save_name)
test_df.to_csv(save_filename,index=False)
print (save_filename, 'done')
# Out:
# efficientnet-b7_0814_17-00-41_submition.csv done

# %%
test_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6086c99c50>]], dtype=object)

# %%
test_df.diagnosis = optR.predict(preds, [0.5, 1.5, 2.5, 3.5])
test_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f60877848d0>]], dtype=object)

# %%
pd.read_csv("0.806.csv").hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f6088f4a080>]], dtype=object)
