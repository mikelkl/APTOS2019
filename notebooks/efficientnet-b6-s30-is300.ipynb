# %%
import os

os.environ["CUDA_VISIBLE_DEVICES"] = "5"

# %%
# %reload_ext autoreload
# %autoreload 2
# %matplotlib inline
import torch
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from matplotlib import style
import seaborn as sns
from sklearn.model_selection import StratifiedKFold
from joblib import load, dump
from sklearn.metrics import cohen_kappa_score
from sklearn.metrics import confusion_matrix
from fastai import *
from fastai.vision import *
from fastai.callbacks import *
from torchvision import models as md
from torch import nn
from torch.nn import functional as F
import re
import math
import collections
from functools import partial
from torch.utils import model_zoo
from sklearn import metrics
from collections import Counter
import json
from efficientnet_pytorch import EfficientNet
from utils import *

# %%
import random

def seed_everything(seed):
    random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
SEED = 2019
seed_everything(SEED)

# %%
current_time = get_BJ_time()
print(current_time)
# Out:
# 0815_00-59-11

# %% [markdown]
# # Reading data and Basic EDA(Exploratory Data Analysis)
#
# Here I am going to open the dataset with pandas, check distribution of labels.

# %%
df_2015 = pd.read_csv('../input/aptos-data-split/df_2015_raw.csv')
df_2019 = pd.read_csv('../input/aptos-data-split/df_2019_sigmaX30.csv')

df = pd.concat([df_2015, df_2019]).reset_index(drop=True) # merge train val together
df['is_valid'] = [False]*df_2015.shape[0] + [True]*df_2019.shape[0]

test_df = pd.read_csv('../input/aptos2019-blindness-detection/sample_submission.csv')

# %%
model_name = 'efficientnet-b6'
bs = 16 #smaller batch size is better for training, but may take longer
sz = 300
# sz = EfficientNet.get_image_size(model_name)  # get model input size
tfms = get_transforms(do_flip=True,flip_vert=True, max_rotate=0, max_zoom=1.2, max_warp=0)

# %%
data = (ImageList.from_df(df=df_2019,path='./',cols='path')
        .split_from_df("is_valid")
        .label_from_df(cols='diagnosis',label_cls=FloatList) 
        .transform(tfms,size=sz,resize_method=ResizeMethod.SQUISH,padding_mode='zeros') 
        .databunch(bs=bs,num_workers=4) 
        .normalize(imagenet_stats)  
       )
data
# Out:
# ImageDataBunch;
#
# Train: LabelList (2929 items)
# x: ImageList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: FloatList
# 0.0,0.0,1.0,2.0,1.0
# Path: .;
#
# Valid: LabelList (733 items)
# x: ImageList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: FloatList
# 2.0,1.0,0.0,4.0,0.0
# Path: .;
#
# Test: None

# %% [markdown]
# # Training (Transfer learning)

# %% [markdown]
# The Kaggle competition used the Cohen's quadratically weighted kappa so I have that here to compare. This is a better metric when dealing with imbalanced datasets like this one, and for measuring inter-rater agreement for categorical classification (the raters being the human-labeled dataset and the neural network predictions). Here is an implementation based on the scikit-learn's implementation, but converted to a pytorch tensor, as that is what fastai uses.

# %%
def qk(y_pred, y):
    return torch.tensor(cohen_kappa_score(torch.round(y_pred), y, weights='quadratic'), device='cuda:0')

# %% [markdown]
# ## EfficientNet

# %%
model = EfficientNet.from_pretrained(model_name, num_classes=1)
# Out:
# Loaded pretrained weights for efficientnet-b6

# %%
learn = Learner(data, 
                model, 
                metrics = [qk],
                callback_fns=[partial(EarlyStoppingCallback, min_delta=0, patience=3)],
                model_dir = '../output/models/')

learn.data.add_test(ImageList.from_df(test_df,
                                      '../input/aptos2019-blindness-detection',
                                      folder='test_images_ben_preprocessing',
                                      suffix='.png'))

# %%
# Freeze layers up to the last one, so weights will not be updated.
# for name, param in learn.model.named_parameters():
#     if name in ["_fc.weight", "_fc.bias"]:
#         param.requires_grad=True
#     else:
#         param.requires_grad=False
        
# Explore lr from `start_lr` to `end_lr` over `num_it` iterations in `learn`. If `stop_div`, stops when loss diverges.
learn.lr_find() 
learn.recorder.plot(suggestion=True)
# Out:
# LR Finder is complete, type {learner_name}.recorder.plot() to see the graph.
# Min numerical gradient: 2.29E-06
# Min loss divided by 10: 1.32E-03

# %%
model_save_name = "{}_{}".format(model_name, current_time)
min_grad_lr = learn.recorder.min_grad_lr
learn.fit_one_cycle(40, 4e-4, callbacks=[SaveModelCallback(learn, every='improvement', name=model_save_name)])
print("Model save as:", model_save_name)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='14' class='' max='40', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       35.00% [14/40 18:29<34:21]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>qk</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td>0</td>
#       <td>1.670985</td>
#       <td>2.069782</td>
#       <td>0.457929</td>
#       <td>01:21</td>
#     </tr>
#     <tr>
#       <td>1</td>
#       <td>0.679869</td>
#       <td>0.558536</td>
#       <td>0.808330</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>2</td>
#       <td>0.497464</td>
#       <td>0.416095</td>
#       <td>0.840132</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>3</td>
#       <td>0.447970</td>
#       <td>0.316802</td>
#       <td>0.872943</td>
#       <td>01:19</td>
#     </tr>
#     <tr>
#       <td>4</td>
#       <td>0.379246</td>
#       <td>0.307977</td>
#       <td>0.880614</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>5</td>
#       <td>0.352400</td>
#       <td>0.293380</td>
#       <td>0.887491</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>6</td>
#       <td>0.356066</td>
#       <td>0.358972</td>
#       <td>0.854215</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>7</td>
#       <td>0.314999</td>
#       <td>0.335040</td>
#       <td>0.864833</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>8</td>
#       <td>0.302439</td>
#       <td>0.257143</td>
#       <td>0.900853</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>9</td>
#       <td>0.241714</td>
#       <td>0.345094</td>
#       <td>0.874503</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>10</td>
#       <td>0.271606</td>
#       <td>0.254646</td>
#       <td>0.904825</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>11</td>
#       <td>0.255311</td>
#       <td>0.331455</td>
#       <td>0.881673</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>12</td>
#       <td>0.240919</td>
#       <td>0.306407</td>
#       <td>0.885784</td>
#       <td>01:18</td>
#     </tr>
#     <tr>
#       <td>13</td>
#       <td>0.212249</td>
#       <td>0.260929</td>
#       <td>0.904209</td>
#       <td>01:18</td>
#     </tr>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='46' class='' max='46', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       100.00% [46/46 00:04<00:00]
#     </div>
# Better model found at epoch 0 with valid_loss value: 2.0697824954986572.
# Better model found at epoch 1 with valid_loss value: 0.5585358142852783.
# Better model found at epoch 2 with valid_loss value: 0.4160948395729065.
# Better model found at epoch 3 with valid_loss value: 0.3168020248413086.
# Better model found at epoch 4 with valid_loss value: 0.3079772889614105.
# Better model found at epoch 5 with valid_loss value: 0.2933804988861084.
# Better model found at epoch 8 with valid_loss value: 0.2571427822113037.
# Better model found at epoch 10 with valid_loss value: 0.25464558601379395.
# Epoch 14: early stopping
# Model save as: efficientnet-b6_0815_00-59-11

# %%
learn.recorder.plot_losses()
learn.recorder.plot_metrics()

# %%
learn.load(model_save_name)
# Out:
# Learner(data=ImageDataBunch;
#
# Train: LabelList (2929 items)
# x: ImageList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: FloatList
# 0.0,0.0,1.0,2.0,1.0
# Path: .;
#
# Valid: LabelList (733 items)
# x: ImageList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: FloatList
# 2.0,1.0,0.0,4.0,0.0
# Path: .;
#
# Test: LabelList (1928 items)
# x: ImageList
# Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300),Image (3, 300, 300)
# y: EmptyLabelList
# ,,,,
# Path: ., model=EfficientNet(
#   (_conv_stem): Conv2dStaticSamePadding(
#     3, 56, kernel_size=(3, 3), stride=(2, 2), bias=False
#     (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#   )
#   (_bn0): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (_blocks): ModuleList(
#     (0): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         56, 56, kernel_size=(3, 3), stride=[1, 1], groups=56, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(56, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         56, 14, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         14, 56, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         56, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (1): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (2): MBConvBlock(
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(3, 3), stride=(1, 1), groups=32, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         32, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 32, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         32, 32, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(32, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (3): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         32, 192, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         192, 192, kernel_size=(3, 3), stride=[2, 2], groups=192, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(192, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         192, 8, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         8, 192, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         192, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (4): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (5): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (6): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (7): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (8): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(3, 3), stride=(1, 1), groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 40, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(40, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (9): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         40, 240, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         240, 240, kernel_size=(5, 5), stride=[2, 2], groups=240, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(240, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         240, 10, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         10, 240, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         240, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (10): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         432, 18, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         18, 432, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (11): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         432, 18, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         18, 432, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (12): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         432, 18, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         18, 432, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (13): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         432, 18, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         18, 432, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (14): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         432, 432, kernel_size=(5, 5), stride=(1, 1), groups=432, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         432, 18, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         18, 432, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         432, 72, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(72, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (15): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         72, 432, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         432, 432, kernel_size=(3, 3), stride=[2, 2], groups=432, bias=False
#         (static_padding): ZeroPad2d(padding=(0, 1, 0, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(432, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         432, 18, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         18, 432, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         432, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (16): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         864, 36, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         36, 864, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (17): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         864, 36, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         36, 864, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (18): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         864, 36, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         36, 864, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (19): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         864, 36, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         36, 864, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (20): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         864, 36, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         36, 864, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (21): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         864, 36, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         36, 864, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (22): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         864, 864, kernel_size=(3, 3), stride=(1, 1), groups=864, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#       )
#       (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         864, 36, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         36, 864, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         864, 144, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (23): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         144, 864, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         864, 864, kernel_size=(5, 5), stride=[1, 1], groups=864, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         864, 36, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         36, 864, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         864, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (24): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1200, 50, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         50, 1200, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (25): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1200, 50, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         50, 1200, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (26): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1200, 50, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         50, 1200, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (27): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1200, 50, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         50, 1200, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (28): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1200, 50, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         50, 1200, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (29): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1200, 50, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         50, 1200, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (30): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1200, 1200, kernel_size=(5, 5), stride=(1, 1), groups=1200, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1200, 50, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         50, 1200, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1200, 200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (31): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         200, 1200, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         1200, 1200, kernel_size=(5, 5), stride=[2, 2], groups=1200, bias=False
#         (static_padding): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         1200, 50, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         50, 1200, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         1200, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (32): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (33): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (34): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (35): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (36): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (37): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (38): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (39): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (40): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn0): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_depthwise_conv): Conv2dStaticSamePadding(
#         2064, 2064, kernel_size=(5, 5), stride=(1, 1), groups=2064, bias=False
#         (static_padding): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#       )
#       (_bn1): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#       (_se_reduce): Conv2dStaticSamePadding(
#         2064, 86, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_se_expand): Conv2dStaticSamePadding(
#         86, 2064, kernel_size=(1, 1), stride=(1, 1)
#         (static_padding): Identity()
#       )
#       (_project_conv): Conv2dStaticSamePadding(
#         2064, 344, kernel_size=(1, 1), stride=(1, 1), bias=False
#         (static_padding): Identity()
#       )
#       (_bn2): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#     )
#     (41): MBConvBlock(
#       (_expand_conv): Conv2dStaticSamePadding(
#         344, 2064, kernel_size=(1, 1), stride=(1, 1), bias=False
# ...
#   (300): Identity()
#   (301): ParameterModule()
#   (302): ParameterModule()
#   (303): Identity()
#   (304): ParameterModule()
#   (305): ParameterModule()
#   (306): Identity()
#   (307): ParameterModule()
#   (308): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (309): Identity()
#   (310): ParameterModule()
#   (311): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (312): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (313): ParameterModule()
#   (314): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (315): Identity()
#   (316): ParameterModule()
#   (317): ParameterModule()
#   (318): Identity()
#   (319): ParameterModule()
#   (320): ParameterModule()
#   (321): Identity()
#   (322): ParameterModule()
#   (323): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (324): Identity()
#   (325): ParameterModule()
#   (326): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (327): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (328): ParameterModule()
#   (329): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (330): Identity()
#   (331): ParameterModule()
#   (332): ParameterModule()
#   (333): Identity()
#   (334): ParameterModule()
#   (335): ParameterModule()
#   (336): Identity()
#   (337): ParameterModule()
#   (338): BatchNorm2d(144, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (339): Identity()
#   (340): ParameterModule()
#   (341): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (342): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (343): ParameterModule()
#   (344): BatchNorm2d(864, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (345): Identity()
#   (346): ParameterModule()
#   (347): ParameterModule()
#   (348): Identity()
#   (349): ParameterModule()
#   (350): ParameterModule()
#   (351): Identity()
#   (352): ParameterModule()
#   (353): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (354): Identity()
#   (355): ParameterModule()
#   (356): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (357): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (358): ParameterModule()
#   (359): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (360): Identity()
#   (361): ParameterModule()
#   (362): ParameterModule()
#   (363): Identity()
#   (364): ParameterModule()
#   (365): ParameterModule()
#   (366): Identity()
#   (367): ParameterModule()
#   (368): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (369): Identity()
#   (370): ParameterModule()
#   (371): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (372): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (373): ParameterModule()
#   (374): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (375): Identity()
#   (376): ParameterModule()
#   (377): ParameterModule()
#   (378): Identity()
#   (379): ParameterModule()
#   (380): ParameterModule()
#   (381): Identity()
#   (382): ParameterModule()
#   (383): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (384): Identity()
#   (385): ParameterModule()
#   (386): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (387): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (388): ParameterModule()
#   (389): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (390): Identity()
#   (391): ParameterModule()
#   (392): ParameterModule()
#   (393): Identity()
#   (394): ParameterModule()
#   (395): ParameterModule()
#   (396): Identity()
#   (397): ParameterModule()
#   (398): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (399): Identity()
#   (400): ParameterModule()
#   (401): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (402): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (403): ParameterModule()
#   (404): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (405): Identity()
#   (406): ParameterModule()
#   (407): ParameterModule()
#   (408): Identity()
#   (409): ParameterModule()
#   (410): ParameterModule()
#   (411): Identity()
#   (412): ParameterModule()
#   (413): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (414): Identity()
#   (415): ParameterModule()
#   (416): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (417): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (418): ParameterModule()
#   (419): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (420): Identity()
#   (421): ParameterModule()
#   (422): ParameterModule()
#   (423): Identity()
#   (424): ParameterModule()
#   (425): ParameterModule()
#   (426): Identity()
#   (427): ParameterModule()
#   (428): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (429): Identity()
#   (430): ParameterModule()
#   (431): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (432): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (433): ParameterModule()
#   (434): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (435): Identity()
#   (436): ParameterModule()
#   (437): ParameterModule()
#   (438): Identity()
#   (439): ParameterModule()
#   (440): ParameterModule()
#   (441): Identity()
#   (442): ParameterModule()
#   (443): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (444): Identity()
#   (445): ParameterModule()
#   (446): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (447): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (448): ParameterModule()
#   (449): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (450): Identity()
#   (451): ParameterModule()
#   (452): ParameterModule()
#   (453): Identity()
#   (454): ParameterModule()
#   (455): ParameterModule()
#   (456): Identity()
#   (457): ParameterModule()
#   (458): BatchNorm2d(200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (459): Identity()
#   (460): ParameterModule()
#   (461): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (462): ZeroPad2d(padding=(1, 2, 1, 2), value=0.0)
#   (463): ParameterModule()
#   (464): BatchNorm2d(1200, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (465): Identity()
#   (466): ParameterModule()
#   (467): ParameterModule()
#   (468): Identity()
#   (469): ParameterModule()
#   (470): ParameterModule()
#   (471): Identity()
#   (472): ParameterModule()
#   (473): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (474): Identity()
#   (475): ParameterModule()
#   (476): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (477): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (478): ParameterModule()
#   (479): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (480): Identity()
#   (481): ParameterModule()
#   (482): ParameterModule()
#   (483): Identity()
#   (484): ParameterModule()
#   (485): ParameterModule()
#   (486): Identity()
#   (487): ParameterModule()
#   (488): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (489): Identity()
#   (490): ParameterModule()
#   (491): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (492): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (493): ParameterModule()
#   (494): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (495): Identity()
#   (496): ParameterModule()
#   (497): ParameterModule()
#   (498): Identity()
#   (499): ParameterModule()
#   (500): ParameterModule()
#   (501): Identity()
#   (502): ParameterModule()
#   (503): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (504): Identity()
#   (505): ParameterModule()
#   (506): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (507): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (508): ParameterModule()
#   (509): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (510): Identity()
#   (511): ParameterModule()
#   (512): ParameterModule()
#   (513): Identity()
#   (514): ParameterModule()
#   (515): ParameterModule()
#   (516): Identity()
#   (517): ParameterModule()
#   (518): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (519): Identity()
#   (520): ParameterModule()
#   (521): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (522): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (523): ParameterModule()
#   (524): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (525): Identity()
#   (526): ParameterModule()
#   (527): ParameterModule()
#   (528): Identity()
#   (529): ParameterModule()
#   (530): ParameterModule()
#   (531): Identity()
#   (532): ParameterModule()
#   (533): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (534): Identity()
#   (535): ParameterModule()
#   (536): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (537): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (538): ParameterModule()
#   (539): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (540): Identity()
#   (541): ParameterModule()
#   (542): ParameterModule()
#   (543): Identity()
#   (544): ParameterModule()
#   (545): ParameterModule()
#   (546): Identity()
#   (547): ParameterModule()
#   (548): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (549): Identity()
#   (550): ParameterModule()
#   (551): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (552): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (553): ParameterModule()
#   (554): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (555): Identity()
#   (556): ParameterModule()
#   (557): ParameterModule()
#   (558): Identity()
#   (559): ParameterModule()
#   (560): ParameterModule()
#   (561): Identity()
#   (562): ParameterModule()
#   (563): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (564): Identity()
#   (565): ParameterModule()
#   (566): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (567): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (568): ParameterModule()
#   (569): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (570): Identity()
#   (571): ParameterModule()
#   (572): ParameterModule()
#   (573): Identity()
#   (574): ParameterModule()
#   (575): ParameterModule()
#   (576): Identity()
#   (577): ParameterModule()
#   (578): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (579): Identity()
#   (580): ParameterModule()
#   (581): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (582): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (583): ParameterModule()
#   (584): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (585): Identity()
#   (586): ParameterModule()
#   (587): ParameterModule()
#   (588): Identity()
#   (589): ParameterModule()
#   (590): ParameterModule()
#   (591): Identity()
#   (592): ParameterModule()
#   (593): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (594): Identity()
#   (595): ParameterModule()
#   (596): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (597): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (598): ParameterModule()
#   (599): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (600): Identity()
#   (601): ParameterModule()
#   (602): ParameterModule()
#   (603): Identity()
#   (604): ParameterModule()
#   (605): ParameterModule()
#   (606): Identity()
#   (607): ParameterModule()
#   (608): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (609): Identity()
#   (610): ParameterModule()
#   (611): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (612): ZeroPad2d(padding=(2, 2, 2, 2), value=0.0)
#   (613): ParameterModule()
#   (614): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (615): Identity()
#   (616): ParameterModule()
#   (617): ParameterModule()
#   (618): Identity()
#   (619): ParameterModule()
#   (620): ParameterModule()
#   (621): Identity()
#   (622): ParameterModule()
#   (623): BatchNorm2d(344, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (624): Identity()
#   (625): ParameterModule()
#   (626): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (627): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (628): ParameterModule()
#   (629): BatchNorm2d(2064, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (630): Identity()
#   (631): ParameterModule()
#   (632): ParameterModule()
#   (633): Identity()
#   (634): ParameterModule()
#   (635): ParameterModule()
#   (636): Identity()
#   (637): ParameterModule()
#   (638): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (639): Identity()
#   (640): ParameterModule()
#   (641): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (642): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (643): ParameterModule()
#   (644): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (645): Identity()
#   (646): ParameterModule()
#   (647): ParameterModule()
#   (648): Identity()
#   (649): ParameterModule()
#   (650): ParameterModule()
#   (651): Identity()
#   (652): ParameterModule()
#   (653): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (654): Identity()
#   (655): ParameterModule()
#   (656): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (657): ZeroPad2d(padding=(1, 1, 1, 1), value=0.0)
#   (658): ParameterModule()
#   (659): BatchNorm2d(3456, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (660): Identity()
#   (661): ParameterModule()
#   (662): ParameterModule()
#   (663): Identity()
#   (664): ParameterModule()
#   (665): ParameterModule()
#   (666): Identity()
#   (667): ParameterModule()
#   (668): BatchNorm2d(576, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (669): Identity()
#   (670): ParameterModule()
#   (671): BatchNorm2d(2304, eps=0.001, momentum=0.010000000000000009, affine=True, track_running_stats=True)
#   (672): Linear(in_features=2304, out_features=1, bias=True)
# )], add_time=True, silent=None)

# %% [markdown]
# # Optimize the Metric
# Optimizing the quadratic kappa metric was an important part of the top solutions in the previous competition. Thankfully, @abhishek has already provided code to do this for us. We will use this to improve the score.

# %%
import scipy as sp

# %%
class OptimizedRounder(object):
    """
    Optimize threshold coefficients.
    """
    def __init__(self):
        self.coef_ = 0

    def _kappa_loss(self, coef, X, y):
        """
        Customized loss function.
        
        :param coef: list, shape=[4]
            Threshold.
        :param X: list, shape=[5]
            Prediction.
        :param y: list, shape=[5]
            Golden label.
        """
        X_p = np.copy(X)
        for i, pred in enumerate(X_p):
            if pred < coef[0]:
                X_p[i] = 0
            elif pred >= coef[0] and pred < coef[1]:
                X_p[i] = 1
            elif pred >= coef[1] and pred < coef[2]:
                X_p[i] = 2
            elif pred >= coef[2] and pred < coef[3]:
                X_p[i] = 3
            else:
                X_p[i] = 4
        
        # Cohen's kappa: a statistic that measures inter-annotator agreement.
        ll = metrics.cohen_kappa_score(y, X_p, weights='quadratic')
        return -ll

    def fit(self, X, y):
        """
        :param X: list, shape=[5]
            Prediction.
        :param y: list, shape=[5]
            Golden label.
        """
        # new function with partial application of the given arguments and keywords.
        loss_partial = partial(self._kappa_loss, X=X, y=y)
        initial_coef = [0.5, 1.5, 2.5, 3.5]
        # Minimization of scalar function of one or more variables.
        self.coef_ = sp.optimize.minimize(loss_partial, initial_coef, method='nelder-mead')
        print(-loss_partial(self.coef_['x']))

    def predict(self, X, coef):
        """
        :param X: list, shape=[5]
            Prediction.
        :param coef: list, shape=[4]
            Threshold.
        """
        X_p = np.copy(X)
        for i, pred in enumerate(X_p):
            if pred < coef[0]:
                X_p[i] = 0
            elif pred >= coef[0] and pred < coef[1]:
                X_p[i] = 1
            elif pred >= coef[1] and pred < coef[2]:
                X_p[i] = 2
            elif pred >= coef[2] and pred < coef[3]:
                X_p[i] = 3
            else:
                X_p[i] = 4
        return X_p

    def coefficients(self):
        return self.coef_['x']

# %%
# Return predictions and targets on `ds_type` dataset.
valid_preds = learn.get_preds(ds_type=DatasetType.Valid)
optR = OptimizedRounder()
optR.fit(valid_preds[0],valid_preds[1])
coefficients = optR.coefficients()
print(coefficients)
# Out:
# 0.91883040704852
# [0.544401 1.52334  2.150518 3.122533]

# %% [markdown]
# # Error Analysis

# %%
valid_pred = optR.predict(valid_preds[0], coefficients)
cm = confusion_matrix(valid_pred,valid_preds[1])

# %%
plot_confusion_matrix(cm, classes=range(5), normalize=False)
# Out:
# Confusion matrix, without normalization
# [[363   2   0   0   0]
#  [  3  37  17   0   1]
#  [  0  28 121   4   9]
#  [  0   1  68  23  28]
#  [  0   0   0   3  25]]

# %%
learn.show_results()

# %% [markdown]
# # Submission

# %%
preds,y = learn.get_preds(DatasetType.Test)
tst_pred = optR.predict(preds, coefficients)
test_df.diagnosis = tst_pred.astype(int)

# %%
save_filename = '{}_submition.csv'.format(model_save_name)
test_df.to_csv(save_filename,index=False)
print (save_filename, 'done')
# Out:
# efficientnet-b6_0815_00-59-11_submition.csv done

# %%
test_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0d21c5d4e0>]], dtype=object)

# %%
test_df.diagnosis = optR.predict(preds, [0.5, 1.5, 2.5, 3.5])
test_df.hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0d21bd1c18>]], dtype=object)

# %%
pd.read_csv("0.806.csv").hist()
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x7f0d21b8af60>]], dtype=object)
